# %%
import pandas as pd

# %%
df = pd.read_csv('resumen_experimentos.csv')

# %%
df.head()
# Out:
#   experiment_id                fecha modelo  dataset discretizacion  n_puntos  \
# 0    0CC94F0622  2026-07-04T15:38:50     AA  rrlyrae  interpolacion        50
# 1    5B023BC338  2026-07-04T15:39:14     AA  rrlyrae  interpolacion        50
# 2    D7BF314E3D  2026-07-04T15:39:45     AA  rrlyrae  interpolacion        50
# 3    B31A1FAB02  2026-07-04T15:55:17     AA  rrlyrae  interpolacion        50
# 4    6374DCC13F  2026-07-04T15:56:01     AA  rrlyrae  interpolacion        50
#
#    n_muestras normalizacion inicializacion optimizacion  ...  \
# 0      1000.0        minmax         random  alternating  ...
# 1      1000.0        minmax            pca  alternating  ...
# 2      1000.0        minmax   furthest_sum  alternating  ...
# 3      1000.0        minmax         random          pgd  ...
# 4      1000.0        minmax            pca          pgd  ...
#
#    version_algoritmo  loss_final  purity  mean_activation  silhouette  \
# ...

# %%
df.columns
# Out:
# Index(['experiment_id', 'fecha', 'modelo', 'dataset', 'discretizacion',
#        'n_puntos', 'n_muestras', 'normalizacion', 'inicializacion',
#        'optimizacion', 'K', 'max_iter', 'seed', 'n_estrellas', 'n_variables',
#        'error_fro', 'error_rel', 'error_per_sample_mean',
#        'error_per_sample_std', 'error_per_sample_min', 'error_per_sample_max',
#        'tiempo_segundos', 'estado', 'convergio', 'iteraciones_reales',
#        'tiempo_por_iteracion', 'version_algoritmo', 'loss_final', 'purity',
#        'mean_activation', 'silhouette', 'davies_bouldin', 'ruta_experimento',
#        'suavizado', 'experimento_final', 'estado_metricas'],
#       dtype='object')

# %%
df.plot("davies_bouldin", "purity", kind="scatter")
# Out:
# <Axes: xlabel='davies_bouldin', ylabel='purity'>

# %%
df[["davies_bouldin", "purity"]]
# Out:
#      davies_bouldin    purity
# 0          1.542342  0.834000
# 1          1.542342  0.834000
# 2          1.542342  0.834000
# 3          3.110946  0.685000
# 4          1.698831  0.781000
# ..              ...       ...
# 109        1.506049  0.905000
# 110        1.497713  0.912200
# 111        1.504434  0.913326
# 112        1.388403  0.913750
# 113        1.503019  0.913316
#
# [114 rows x 2 columns]

# %%
df = pd.read_csv('resumen_rrlyrae.csv')

# %%
df.columns
# Out:
# Index(['dataset', 'discretizacion', 'n_puntos', 'optimizacion', 'K',
#        'error_rel', 'error_fro', 'convergio', 'iteraciones_reales',
#        'tiempo_segundos', 'ruta_experimento'],
#       dtype='object')
